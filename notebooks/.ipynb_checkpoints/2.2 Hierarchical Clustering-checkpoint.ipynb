# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.decomposition import PCA
import fastcluster
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import fcluster
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist

# %%
# Configuración de números flotantes a 3 decimales
pd.set_option('display.float_format','{:.2f}'.format)

# Estilo de visualización
sns.set_style("darkgrid")#, {"grid.color": ".6", "grid.linestyle": ":"})

# %%
RFM_DATA_PATH = os.path.join('..','datasets','processed','rfm_dataset.csv')
data = pd.read_csv(RFM_DATA_PATH, index_col='Customer ID') # RFM dataset

# %%
# %run ../auxiliar_functions/plotDistributions.py
    
plotDistributions(data, 'Distribución de las variables')

# %%
data.describe().T
# Out:
#                count   mean    std      min   25%    50%    75%     max
# Recency       793.00 147.80 186.21     1.00 31.00  76.00 184.00 1166.00
# Frequency     793.00  12.60   6.24     1.00  8.00  12.00  16.00   37.00
# MonetaryValue 793.00 361.16 894.26 -6626.39 36.61 227.83 560.01 8981.32

# %% [markdown]
# ### Transformación de los datos

# %%
# Yeo-Johnson Transformation
pt = PowerTransformer(method='box-cox')
ms = MinMaxScaler(feature_range=(-3,3))

transformer = ColumnTransformer(transformers=[('box-cox', pt, ['Recency']),
                              ('standarizer', ms, ['Frequency', 'MonetaryValue'])])

scaled = transformer.fit_transform(data)

# Variables escaladas - DataFrame
scaled = pd.DataFrame(scaled, index=data.index, columns=data.columns)
scaled.sample(5)
# Out:
#              Recency  Frequency  MonetaryValue
# Customer ID
# JE-16165       -0.96      -2.00          -0.15
# DE-13255        1.95      -1.67          -0.27
# GW-14605       -0.74      -1.67          -0.56
# MO-17950        0.68      -2.50          -0.48
# CC-12550       -0.76      -2.50          -0.44

# %%
plotDistributions(scaled, 'Distribución de las variables transformadas')

# %%
scaled.describe().T
# Out:
#                count  mean  std   min   25%   50%   75%  max
# Recency       793.00  0.00 1.00 -2.74 -0.69 -0.02  0.70 2.43
# Frequency     793.00 -1.07 1.04 -3.00 -1.83 -1.17 -0.50 3.00
# MonetaryValue 793.00 -0.31 0.34 -3.00 -0.44 -0.37 -0.24 3.00

# %% [markdown]
# ### Dimensionality Reduction

# %%
pca = PCA(n_components=3, random_state=0)
scaled_pca = pca.fit_transform(scaled)
pca.explained_variance_ratio_
# Out:
# array([0.59573661, 0.35333045, 0.05093294])

# %%
pca_ = PCA(n_components=2, random_state=0)
scaled_pca = pca_.fit_transform(scaled)
pca_.explained_variance_ratio_
# Out:
# array([0.59573661, 0.35333045])

# %%
# Modelo de segmentación jerárquica
hierarchy_model = fastcluster.linkage_vector(scaled_pca, method='ward', metric='euclidean')

# Dendrograma
dendrogram = dendrogram(hierarchy_model)

# Visualización del dendrograma
plt.xlabel(None)
plt.show()

# %%
# Punto de corte
cluster_labels = fcluster(hierarchy_model, 22, criterion='distance')

hierarchicalData = data.copy()

# Asignación de las etiquetas de clusters a los datos
hierarchicalData['ClusterLabels_H'] = cluster_labels

hierarchicalData = hierarchicalData.groupby('ClusterLabels_H').agg({'Recency':'mean',
                                                   'Frequency':'mean',
                                                   'MonetaryValue':['mean','count']})


hierarchicalData
# Out:
#                 Recency Frequency MonetaryValue
#                    mean      mean          mean count
# ClusterLabels_H
# 1                 74.28     20.51        580.69   213
# 2                503.90      8.15        270.33   126
# 3                 83.47     10.13        283.37   454

# %%
data['cluster'] = cluster_labels
fig, ax = plt.subplots(1,3, figsize=(18,6))
for i, feat in enumerate(['Frequency','Recency','MonetaryValue']):
    sns.boxplot(x='cluster', y=feat, data=data,ax=ax[i])
    ax[i].set_title(feat)
plt.savefig(os.path.join('..','img','hierachical_clusters_boxplots_dist.png'))
plt.show()
